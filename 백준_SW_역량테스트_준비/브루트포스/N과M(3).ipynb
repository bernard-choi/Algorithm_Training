# %%
a,b = map(int,input().split())

answer_list = [0] * b
check = [False] * (a+1)

def go(n,m,index):
    if index == m:
        for i in range(m):
            print(answer_list[i], end = ' ')
        print()
        return
    
    for i in range(1,n+1):
#         if check[i] == True: ## 여기만 뺴면 됨
#             continue
            
        check[i] = True
        answer_list[index] = i
        go(n,m,index+1) ## 각 층별로 확정짓는다 [1,2] 확정되면
        check[i] = False ## 

go(a,b,0)
# Out:
# 4 3
# 1 1 1
# 1 1 2
# 1 1 3
# 1 1 4
# 1 2 1
# 1 2 2
# 1 2 3
# 1 2 4
# 1 3 1
# 1 3 2
# 1 3 3
# 1 3 4
# 1 4 1
# 1 4 2
# 1 4 3
# 1 4 4
# 2 1 1
# 2 1 2
# 2 1 3
# 2 1 4
# 2 2 1
# 2 2 2
# 2 2 3
# 2 2 4
# 2 3 1
# 2 3 2
# 2 3 3
# 2 3 4
# 2 4 1
# 2 4 2
# 2 4 3
# 2 4 4
# 3 1 1
# 3 1 2
# 3 1 3
# 3 1 4
# 3 2 1
# 3 2 2
# 3 2 3
# 3 2 4
# 3 3 1
# 3 3 2
# 3 3 3
# 3 3 4
# 3 4 1
# 3 4 2
# 3 4 3
# 3 4 4
# 4 1 1
# 4 1 2
# 4 1 3
# 4 1 4
# 4 2 1
# 4 2 2
# 4 2 3
# 4 2 4
# 4 3 1
# 4 3 2
# 4 3 3
# 4 3 4
# 4 4 1
# 4 4 2
# 4 4 3
# 4 4 4
