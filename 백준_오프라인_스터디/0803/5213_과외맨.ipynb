# %%
input_matrix = []
n = int(input())
# Out:
# 2

# %%
input_matrix = []
for i in range(n*n - (n//2)):
    temp = []

    if (i) % 2 != 1:
        temp.extend(list(map(int,input().split())))
    if (i) % 2 == 1:
        temp.extend([0])
        temp.extend(list(map(int,input().split())))
        temp.extend([0])
        
    input_matrix.append(temp)
# Out:
# 1 1
# 1 1
# 1 1

# %% [markdown]
# # 3 % 2

# %%
input_....














\
# Out:
# [[1, 1], [0, 1, 1, 0], [1, 1]]

# %%
n*2*n - 2*(n//2)
# Out:
# 46
